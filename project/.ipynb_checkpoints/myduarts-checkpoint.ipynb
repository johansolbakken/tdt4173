# %%
import pandas as pd
import numpy as np
from darts import TimeSeries
from darts.models import LightGBMModel
import lightgbm as lgb

# %%
import pandas as pd
import numpy as np
from darts import TimeSeries
from darts.models import LightGBMModel
import lightgbm as lgb

# Load ais_train.csv with separator '|'
train_df = pd.read_csv('ais_train.csv', sep='|')
train_df['time'] = pd.to_datetime(train_df['time'])


# Load ais_test.csv with separator ','
test_df = pd.read_csv('ais_test.csv', sep=',')
test_df['time'] = pd.to_datetime(test_df['time'])

# Use 'vesselId' instead of 'vessel_id'
# Select only vessel IDs that are in both train and test datasets
common_vessel_ids = set(train_df['vesselId']).intersection(set(test_df['vesselId']))
train_df = train_df[train_df['vesselId'].isin(common_vessel_ids)]

# Group the training data by vesselId
groups = train_df.groupby('vesselId')

# Initialize dictionaries to store TimeSeries objects and last training times
timeseries_dict = {}
last_train_time = {}

# Process each vesselId group
for vessel_id, group_df in groups:
    # Sort on time
    group_df = group_df.sort_values('time')
    # Set index to time
    group_df = group_df.set_index('time')
    # Select features (latitude and longitude)
    features_df = group_df[['latitude', 'longitude']]
    # Resample data to hourly frequency with mean and linear interpolation
    features_df = features_df.resample('h').mean().interpolate(method='cubic') 
    # Create Darts TimeSeries object
    ts = TimeSeries.from_dataframe(features_df, value_cols=['latitude', 'longitude'])
    # Store the TimeSeries object and last training time
    timeseries_dict[vessel_id] = ts
    last_train_time[vessel_id] = features_df.index.max()

# Initialize a dictionary to store predictions
predictions = {}

# Fit LightGBM models and predict for each TimeSeries object
for vessel_id, ts in timeseries_dict.items():
    # Get the last training time
    last_time = last_train_time[vessel_id]
    # Get test times for this vessel
    vessel_test_df = test_df[test_df['vesselId'] == vessel_id]
    test_times = vessel_test_df['time']
    # Compute the time differences in hours
    time_diffs = (test_times - last_time).dt.total_seconds() / 3600
    # Get the maximum forecast horizon needed
    max_n = int(np.ceil(time_diffs.max()))
    if max_n <= 0:
        continue  # Skip if no future times to predict
    # Initialize LightGBM model with lag parameters
    model = LightGBMModel(
        lags=48, # the correct value is between 48 and 96
        #learning_rate=0.1,
        #n_estimators=50,
        #max_depth=10,
    )
    # Fit the model
    model.fit(ts)
    # Predict up to the maximum horizon needed
    forecast = model.predict(max_n)
    # Store the forecast and last time
    predictions[vessel_id] = (forecast, last_time)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001894 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 44.152453
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001031 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score -4.685515
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001409 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2987, number of used features: 96
# [LightGBM] [Info] Start training from score 24.946483
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001888 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2987, number of used features: 96
# [LightGBM] [Info] Start training from score 21.324953
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001197 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3019, number of used features: 96
# [LightGBM] [Info] Start training from score 4.679117
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001334 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3019, number of used features: 96
# [LightGBM] [Info] Start training from score 105.944790
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001045 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3019, number of used features: 96
# [LightGBM] [Info] Start training from score 32.514100
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001616 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3019, number of used features: 96
# [LightGBM] [Info] Start training from score 7.436907
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001164 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2988, number of used features: 96
# [LightGBM] [Info] Start training from score 43.497285
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001812 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2988, number of used features: 96
# [LightGBM] [Info] Start training from score -31.964571
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001057 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2776, number of used features: 96
# [LightGBM] [Info] Start training from score 21.846876
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001029 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2776, number of used features: 96
# [LightGBM] [Info] Start training from score 44.592500
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001157 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3018, number of used features: 96
# [LightGBM] [Info] Start training from score -15.556735
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001066 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3018, number of used features: 96
# [LightGBM] [Info] Start training from score 126.467901
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001123 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3016, number of used features: 96
# [LightGBM] [Info] Start training from score 36.173383
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001141 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3016, number of used features: 96
# [LightGBM] [Info] Start training from score -42.464928
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001115 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 15.711397
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000989 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 52.111197
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001170 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2995, number of used features: 96
# [LightGBM] [Info] Start training from score 2.238355
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001060 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2995, number of used features: 96
# [LightGBM] [Info] Start training from score 87.494595
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001079 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2976, number of used features: 96
# [LightGBM] [Info] Start training from score -1.281315
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001086 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2976, number of used features: 96
# [LightGBM] [Info] Start training from score 83.473103
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001032 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2766, number of used features: 96
# [LightGBM] [Info] Start training from score 20.232112
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001801 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2766, number of used features: 96
# [LightGBM] [Info] Start training from score 11.910398
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001220 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3019, number of used features: 96
# [LightGBM] [Info] Start training from score 7.032904
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001165 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3019, number of used features: 96
# [LightGBM] [Info] Start training from score 71.590066
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001292 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score -22.486619
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002189 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 102.974741
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001316 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3002, number of used features: 96
# [LightGBM] [Info] Start training from score 39.314336
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001183 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3002, number of used features: 96
# [LightGBM] [Info] Start training from score 10.150111
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001434 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2955, number of used features: 96
# [LightGBM] [Info] Start training from score 5.772232
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001387 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2955, number of used features: 96
# [LightGBM] [Info] Start training from score 44.087902
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001348 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 14.625807
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002621 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 17.740535
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001507 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2967, number of used features: 96
# [LightGBM] [Info] Start training from score 19.036844
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001210 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2967, number of used features: 96
# [LightGBM] [Info] Start training from score 40.994096
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001112 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2789, number of used features: 96
# [LightGBM] [Info] Start training from score 40.447758
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001008 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2789, number of used features: 96
# [LightGBM] [Info] Start training from score -43.561581
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001113 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 40.229870
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001659 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score -44.708665
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001145 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2933, number of used features: 96
# [LightGBM] [Info] Start training from score -2.577065
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001038 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2933, number of used features: 96
# [LightGBM] [Info] Start training from score 51.163315
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001272 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 18.228909
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001157 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 65.263354
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001054 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2952, number of used features: 96
# [LightGBM] [Info] Start training from score -8.303424
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001076 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2952, number of used features: 96
# [LightGBM] [Info] Start training from score 91.866701
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001246 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 16.435269
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001926 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 19.386003
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000972 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2879, number of used features: 96
# [LightGBM] [Info] Start training from score 38.567075
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000935 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2879, number of used features: 96
# [LightGBM] [Info] Start training from score -50.934897
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001085 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2987, number of used features: 96
# [LightGBM] [Info] Start training from score 11.921718
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001124 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2987, number of used features: 96
# [LightGBM] [Info] Start training from score 54.989916
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001553 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2764, number of used features: 96
# [LightGBM] [Info] Start training from score 13.167388
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001326 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2764, number of used features: 96
# [LightGBM] [Info] Start training from score 13.563944
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001038 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2750, number of used features: 96
# [LightGBM] [Info] Start training from score -7.556019
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001014 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2750, number of used features: 96
# [LightGBM] [Info] Start training from score 143.868799
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001454 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2801, number of used features: 96
# [LightGBM] [Info] Start training from score 17.965607
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001068 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2801, number of used features: 96
# [LightGBM] [Info] Start training from score 13.546662
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000957 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2630, number of used features: 96
# [LightGBM] [Info] Start training from score 8.734167
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001357 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2630, number of used features: 96
# [LightGBM] [Info] Start training from score 47.531661
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001690 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3019, number of used features: 96
# [LightGBM] [Info] Start training from score 0.357767
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001947 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3019, number of used features: 96
# [LightGBM] [Info] Start training from score 62.764070
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001006 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2991, number of used features: 96
# [LightGBM] [Info] Start training from score 8.923840
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001178 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2991, number of used features: 96
# [LightGBM] [Info] Start training from score 104.925390
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002434 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2968, number of used features: 96
# [LightGBM] [Info] Start training from score -5.718644
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001142 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2968, number of used features: 96
# [LightGBM] [Info] Start training from score -59.914625
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002054 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2992, number of used features: 96
# [LightGBM] [Info] Start training from score 39.119922
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001004 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2992, number of used features: 96
# [LightGBM] [Info] Start training from score -26.180499
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001159 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 37.760996
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001295 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score -27.757922
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001017 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 13.717721
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000998 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score -5.401425
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001117 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2874, number of used features: 96
# [LightGBM] [Info] Start training from score -21.384341
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001142 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2874, number of used features: 96
# [LightGBM] [Info] Start training from score -16.010425
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001143 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3006, number of used features: 96
# [LightGBM] [Info] Start training from score 6.920438
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001059 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3006, number of used features: 96
# [LightGBM] [Info] Start training from score -15.355200
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001512 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 22.512617
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001813 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score -3.007640
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001116 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 1802, number of used features: 96
# [LightGBM] [Info] Start training from score 28.045942
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001208 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 1802, number of used features: 96
# [LightGBM] [Info] Start training from score -9.446345
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001105 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2793, number of used features: 96
# [LightGBM] [Info] Start training from score 18.751993
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001007 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2793, number of used features: 96
# [LightGBM] [Info] Start training from score -12.163539
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001083 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2815, number of used features: 96
# [LightGBM] [Info] Start training from score 19.354571
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001092 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2815, number of used features: 96
# [LightGBM] [Info] Start training from score -5.128911
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001880 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3022, number of used features: 96
# [LightGBM] [Info] Start training from score 42.533056
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001723 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3022, number of used features: 96
# [LightGBM] [Info] Start training from score 8.985924
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000956 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2998, number of used features: 96
# [LightGBM] [Info] Start training from score 41.817352
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002084 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2998, number of used features: 96
# [LightGBM] [Info] Start training from score 6.069642
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001524 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2975, number of used features: 96
# [LightGBM] [Info] Start training from score 43.100374
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001590 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2975, number of used features: 96
# [LightGBM] [Info] Start training from score 9.285181
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001150 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 36.996838
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001157 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score -39.748808
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001106 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3023, number of used features: 96
# [LightGBM] [Info] Start training from score 29.352323
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001130 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3023, number of used features: 96
# [LightGBM] [Info] Start training from score 26.095103
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001998 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 42.584410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001294 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 7.121881
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001141 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2688, number of used features: 96
# [LightGBM] [Info] Start training from score 8.927801
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000976 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2688, number of used features: 96
# [LightGBM] [Info] Start training from score 48.349005
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002040 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 26.005605
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001211 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 19.195877
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001751 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2860, number of used features: 96
# [LightGBM] [Info] Start training from score 18.584999
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001105 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2860, number of used features: 96
# [LightGBM] [Info] Start training from score 75.251467
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001077 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 45.884549
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001028 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 1.175506
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001144 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2964, number of used features: 96
# [LightGBM] [Info] Start training from score 7.966186
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001511 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2964, number of used features: 96
# [LightGBM] [Info] Start training from score 77.338373
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001091 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3009, number of used features: 96
# [LightGBM] [Info] Start training from score 21.066429
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001045 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3009, number of used features: 96
# [LightGBM] [Info] Start training from score 39.778640
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001836 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2898, number of used features: 96
# [LightGBM] [Info] Start training from score 22.505009
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001161 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2898, number of used features: 96
# [LightGBM] [Info] Start training from score 10.662577
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001020 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2740, number of used features: 96
# [LightGBM] [Info] Start training from score 12.814635
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001139 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2740, number of used features: 96
# [LightGBM] [Info] Start training from score 47.514021
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001063 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2806, number of used features: 96
# [LightGBM] [Info] Start training from score 0.081977
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001041 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2806, number of used features: 96
# [LightGBM] [Info] Start training from score 140.447246
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001783 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2647, number of used features: 96
# [LightGBM] [Info] Start training from score 25.465559
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001298 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2647, number of used features: 96
# [LightGBM] [Info] Start training from score -27.145709
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001373 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 42.734970
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000983 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 6.395363
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001112 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2773, number of used features: 96
# [LightGBM] [Info] Start training from score -15042.561057
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001156 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2773, number of used features: 96
# [LightGBM] [Info] Start training from score -1591.567671
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001107 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 27.100487
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002255 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score -5.379873
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001086 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2983, number of used features: 96
# [LightGBM] [Info] Start training from score 26.142859
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001285 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2983, number of used features: 96
# [LightGBM] [Info] Start training from score 37.896884
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001333 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2694, number of used features: 96
# [LightGBM] [Info] Start training from score 28.670956
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001053 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2694, number of used features: 96
# [LightGBM] [Info] Start training from score 15.758761
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001891 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3003, number of used features: 96
# [LightGBM] [Info] Start training from score 11.919384
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002189 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3003, number of used features: 96
# [LightGBM] [Info] Start training from score 1.849542
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001096 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2702, number of used features: 96
# [LightGBM] [Info] Start training from score 27.471712
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001081 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2702, number of used features: 96
# [LightGBM] [Info] Start training from score -15.704185
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002354 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2016, number of used features: 96
# [LightGBM] [Info] Start training from score 26.724503
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001039 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2016, number of used features: 96
# [LightGBM] [Info] Start training from score 21.769295
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001050 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2746, number of used features: 96
# [LightGBM] [Info] Start training from score 42.432859
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001029 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2746, number of used features: 96
# [LightGBM] [Info] Start training from score -24.749021
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001211 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2504, number of used features: 96
# [LightGBM] [Info] Start training from score 19.112268
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001594 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2504, number of used features: 96
# [LightGBM] [Info] Start training from score 4.957131
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001670 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score -3.373053
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001803 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 70.544945
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001385 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3005, number of used features: 96
# [LightGBM] [Info] Start training from score 41.889237
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001145 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# ...
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 8.177220
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001022 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 54.073034
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001369 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 8.181477
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000985 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2868, number of used features: 96
# [LightGBM] [Info] Start training from score 20.583179
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000997 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2868, number of used features: 96
# [LightGBM] [Info] Start training from score 59.808119
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001880 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3009, number of used features: 96
# [LightGBM] [Info] Start training from score 54.049618
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002628 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3009, number of used features: 96
# [LightGBM] [Info] Start training from score 5.463316
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001864 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3019, number of used features: 96
# [LightGBM] [Info] Start training from score 54.816056
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001077 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3019, number of used features: 96
# [LightGBM] [Info] Start training from score 8.494130
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001019 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 51.886246
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001161 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 1.651218
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001542 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2857, number of used features: 96
# [LightGBM] [Info] Start training from score 34.614420
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001102 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2857, number of used features: 96
# [LightGBM] [Info] Start training from score -4.248875
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001554 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2803, number of used features: 96
# [LightGBM] [Info] Start training from score 19.832810
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002260 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2803, number of used features: 96
# [LightGBM] [Info] Start training from score -43.030635
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000969 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2690, number of used features: 96
# [LightGBM] [Info] Start training from score -1.875737
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001173 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2690, number of used features: 96
# [LightGBM] [Info] Start training from score -30.158464
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001080 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3001, number of used features: 96
# [LightGBM] [Info] Start training from score 49.651275
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001813 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3001, number of used features: 96
# [LightGBM] [Info] Start training from score -1.071698
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001033 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 47.989152
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001422 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score -0.517485
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001208 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2906, number of used features: 96
# [LightGBM] [Info] Start training from score 25.132841
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001881 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2906, number of used features: 96
# [LightGBM] [Info] Start training from score 32.185939
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001718 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 52.429102
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000931 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 1.678996
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000995 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2967, number of used features: 96
# [LightGBM] [Info] Start training from score 35.231077
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001441 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2967, number of used features: 96
# [LightGBM] [Info] Start training from score 137.706954
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001094 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2324, number of used features: 96
# [LightGBM] [Info] Start training from score 31.163551
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000906 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2324, number of used features: 96
# [LightGBM] [Info] Start training from score 123.666284
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001023 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2546, number of used features: 96
# [LightGBM] [Info] Start training from score 3.219382
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003491 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2546, number of used features: 96
# [LightGBM] [Info] Start training from score 151.326015
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001218 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2922, number of used features: 96
# [LightGBM] [Info] Start training from score -6.031319
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000994 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2922, number of used features: 96
# [LightGBM] [Info] Start training from score 143.589183
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001025 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2785, number of used features: 96
# [LightGBM] [Info] Start training from score 36.253225
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001088 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 2785, number of used features: 96
# [LightGBM] [Info] Start training from score -58.614484
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001252 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 47.823613
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001038 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score -1.574187
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001374 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 47.823613
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001746 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score -1.574187
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001114 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 48.560800
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001026 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score -3.224945
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001809 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 55.102228
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001102 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 15.565117
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001145 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score 49.802038
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001408 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3024, number of used features: 96
# [LightGBM] [Info] Start training from score -0.430651
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001130 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3002, number of used features: 96
# [LightGBM] [Info] Start training from score 55.803337
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001212 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 24480
# [LightGBM] [Info] Number of data points in the train set: 3002, number of used features: 96
# [LightGBM] [Info] Start training from score 12.408218

# %%
# Initialize a list to store submission rows
submission_rows = []

# Generate predictions for the submission file
for idx, row in test_df.iterrows():
    vessel_id = row['vesselId']
    test_time = row['time']
    test_id = row['ID']  # Assuming 'ID' column exists in test_df
    # Check if predictions are available for this vessel_id
    if vessel_id in predictions:
        forecast_ts, last_time = predictions[vessel_id]
        time_diff = (test_time - last_time).total_seconds() / 3600
        index = int(np.round(time_diff)) - 1  # Adjust index since forecast starts from last_time + 1 hour
        # Convert forecast_ts to DataFrame
        forecast_df = forecast_ts.pd_dataframe()
        # Check if index is within forecast horizon
        if 0 <= index < len(forecast_df):
            predicted_lat = forecast_df['latitude'].iloc[index]
            predicted_lon = forecast_df['longitude'].iloc[index]
        else:
            predicted_lat = np.nan
            predicted_lon = np.nan
    else:
        predicted_lat = np.nan
        predicted_lon = np.nan
    # Append the prediction to the submission list
    submission_rows.append({
        'ID': test_id,
        'longitude_predicted': predicted_lon,
        'latitude_predicted': predicted_lat
    })

# Create a submission DataFrame from the list
submission_df = pd.DataFrame(submission_rows)

# Save the submission file
submission_df.to_csv('submission.csv', index=False)

print(submission_df)
# Out:
#           ID  longitude_predicted  latitude_predicted
# 0          0           -81.461222           31.310978
# 1          1           120.314674           14.862437
# 2          2            10.822518           38.407707
# 3          3           172.865032          -43.499429
# 4          4            -6.323423           48.275540
# ...      ...                  ...                 ...
# 51734  51734           -82.198316           35.719752
# 51735  51735           143.251324           41.575244
# 51736  51736           141.838346           35.388105
# 51737  51737            16.513350           56.034454
# 51738  51738             9.654495           56.098796
#
# [51739 rows x 3 columns]

# %%
submission_df.describe()
# Out:
#                  ID  longitude_predicted  latitude_predicted
# count  51739.000000         51739.000000        51739.000000
# mean   25869.000000             9.580488           38.905957
# std    14935.907126            56.603657           21.781336
# min        0.000000          -122.865196          -43.499429
# 25%    12934.500000            -5.512486           36.076367
# 50%    25869.000000             4.212553           43.386201
# 75%    38803.500000            13.508536           52.442675
# max    51738.000000           177.860568           63.679121
