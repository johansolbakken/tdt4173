# %%
import pandas as pd
import numpy as np
from darts import TimeSeries
from darts.models import LightGBMModel
import lightgbm as lgb

# %%
import pandas as pd
import numpy as np
from darts import TimeSeries
from darts.models import LightGBMModel
import lightgbm as lgb

# Load ais_train.csv with separator '|'
train_df = pd.read_csv('ais_train.csv', sep='|')
train_df['time'] = pd.to_datetime(train_df['time'])

# Load ais_test.csv with separator ','
test_df = pd.read_csv('ais_test.csv', sep=',')
test_df['time'] = pd.to_datetime(test_df['time'])

# Use 'vesselId' instead of 'vessel_id'
# Select only vessel IDs that are in both train and test datasets
common_vessel_ids = set(train_df['vesselId']).intersection(set(test_df['vesselId']))
train_df = train_df[train_df['vesselId'].isin(common_vessel_ids)]

# Group the training data by vesselId
groups = train_df.groupby('vesselId')

# Initialize dictionaries to store TimeSeries objects and last training times
timeseries_dict = {}
last_train_time = {}

# Process each vesselId group
for vessel_id, group_df in groups:
    # Sort on time
    group_df = group_df.sort_values('time')
    # Set index to time
    group_df = group_df.set_index('time')
    # Select features (latitude and longitude)
    features_df = group_df[['latitude', 'longitude']]
    # Resample data to hourly frequency with mean and linear interpolation
    features_df = features_df.resample('H').mean().interpolate(method='linear')
    # Create Darts TimeSeries object
    ts = TimeSeries.from_dataframe(features_df, value_cols=['latitude', 'longitude'])
    # Store the TimeSeries object and last training time
    timeseries_dict[vessel_id] = ts
    last_train_time[vessel_id] = features_df.index.max()

# Initialize a dictionary to store predictions
predictions = {}

# Fit LightGBM models and predict for each TimeSeries object
for vessel_id, ts in timeseries_dict.items():
    # Get the last training time
    last_time = last_train_time[vessel_id]
    # Get test times for this vessel
    vessel_test_df = test_df[test_df['vesselId'] == vessel_id]
    test_times = vessel_test_df['time']
    # Compute the time differences in hours
    time_diffs = (test_times - last_time).dt.total_seconds() / 3600
    # Get the maximum forecast horizon needed
    max_n = int(np.ceil(time_diffs.max()))
    if max_n <= 0:
        continue  # Skip if no future times to predict
    # Initialize LightGBM model with lag parameters
    model = LightGBMModel(lags=24)
    # Fit the model
    model.fit(ts)
    # Predict up to the maximum horizon needed
    forecast = model.predict(max_n)
    # Store the forecast and last time
    predictions[vessel_id] = (forecast, last_time)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000505 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 44.191823
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000472 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score -4.579224
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000806 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3011, number of used features: 48
# [LightGBM] [Info] Start training from score 26.621231
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001582 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3011, number of used features: 48
# [LightGBM] [Info] Start training from score 37.572420
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000504 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3043, number of used features: 48
# [LightGBM] [Info] Start training from score 4.437989
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000588 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3043, number of used features: 48
# [LightGBM] [Info] Start training from score 105.448884
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000819 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3043, number of used features: 48
# [LightGBM] [Info] Start training from score 34.895702
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000449 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3043, number of used features: 48
# [LightGBM] [Info] Start training from score 11.852917
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000516 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3012, number of used features: 48
# [LightGBM] [Info] Start training from score 43.846394
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000743 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3012, number of used features: 48
# [LightGBM] [Info] Start training from score -31.483232
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000496 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 48
# [LightGBM] [Info] Start training from score 22.510847
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000459 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2800, number of used features: 48
# [LightGBM] [Info] Start training from score 45.043527
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000501 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3042, number of used features: 48
# [LightGBM] [Info] Start training from score -16.257207
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000575 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3042, number of used features: 48
# [LightGBM] [Info] Start training from score 126.604949
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000497 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3040, number of used features: 48
# [LightGBM] [Info] Start training from score 37.837742
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000484 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3040, number of used features: 48
# [LightGBM] [Info] Start training from score -41.666289
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000520 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 15.436500
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000793 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 53.400400
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000483 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3019, number of used features: 48
# [LightGBM] [Info] Start training from score 3.301560
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000796 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3019, number of used features: 48
# [LightGBM] [Info] Start training from score 89.034293
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000448 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3000, number of used features: 48
# [LightGBM] [Info] Start training from score -1.647460
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000485 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3000, number of used features: 48
# [LightGBM] [Info] Start training from score 84.750452
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000487 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2790, number of used features: 48
# [LightGBM] [Info] Start training from score 18.548655
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000437 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2790, number of used features: 48
# [LightGBM] [Info] Start training from score 12.292946
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000598 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3043, number of used features: 48
# [LightGBM] [Info] Start training from score 7.473342
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000799 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3043, number of used features: 48
# [LightGBM] [Info] Start training from score 72.840631
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000433 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score -12.023451
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000460 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 91.583723
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000366 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3026, number of used features: 48
# [LightGBM] [Info] Start training from score 39.125465
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001160 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3026, number of used features: 48
# [LightGBM] [Info] Start training from score 10.025274
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000452 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2979, number of used features: 48
# [LightGBM] [Info] Start training from score 4.416295
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000495 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2979, number of used features: 48
# [LightGBM] [Info] Start training from score 45.527010
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000606 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 14.447862
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000767 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 20.771840
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000887 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2991, number of used features: 48
# [LightGBM] [Info] Start training from score 21.378461
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000501 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2991, number of used features: 48
# [LightGBM] [Info] Start training from score 49.428861
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000483 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2813, number of used features: 48
# [LightGBM] [Info] Start training from score 41.265699
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000853 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2813, number of used features: 48
# [LightGBM] [Info] Start training from score -42.699795
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000597 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 41.099066
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000851 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score -44.489292
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000566 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2957, number of used features: 48
# [LightGBM] [Info] Start training from score -3.033383
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000869 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2957, number of used features: 48
# [LightGBM] [Info] Start training from score 49.646658
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000835 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 11.856236
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000507 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 59.677326
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000558 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2976, number of used features: 48
# [LightGBM] [Info] Start training from score -8.304723
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000679 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2976, number of used features: 48
# [LightGBM] [Info] Start training from score 91.379955
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000844 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 15.915872
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000791 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 21.460395
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000576 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2903, number of used features: 48
# [LightGBM] [Info] Start training from score 39.217815
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000488 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2903, number of used features: 48
# [LightGBM] [Info] Start training from score -50.042970
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001085 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3011, number of used features: 48
# [LightGBM] [Info] Start training from score 13.321591
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000405 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3011, number of used features: 48
# [LightGBM] [Info] Start training from score 54.796523
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000519 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2788, number of used features: 48
# [LightGBM] [Info] Start training from score 13.868125
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000819 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2788, number of used features: 48
# [LightGBM] [Info] Start training from score 14.106627
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000501 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2774, number of used features: 48
# [LightGBM] [Info] Start training from score -7.380309
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000945 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2774, number of used features: 48
# [LightGBM] [Info] Start training from score 143.318703
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000490 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2825, number of used features: 48
# [LightGBM] [Info] Start training from score 21.486341
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000351 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2825, number of used features: 48
# [LightGBM] [Info] Start training from score 13.149264
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000474 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2654, number of used features: 48
# [LightGBM] [Info] Start training from score 20.501947
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000397 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2654, number of used features: 48
# [LightGBM] [Info] Start training from score 46.984526
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000529 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3043, number of used features: 48
# [LightGBM] [Info] Start training from score 1.864794
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000435 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3043, number of used features: 48
# [LightGBM] [Info] Start training from score 62.328490
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000676 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3015, number of used features: 48
# [LightGBM] [Info] Start training from score 9.620756
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000443 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3015, number of used features: 48
# [LightGBM] [Info] Start training from score 104.032655
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000513 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2992, number of used features: 48
# [LightGBM] [Info] Start training from score -7.460799
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000500 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2992, number of used features: 48
# [LightGBM] [Info] Start training from score -60.327742
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000946 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3016, number of used features: 48
# [LightGBM] [Info] Start training from score 39.887104
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000529 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3016, number of used features: 48
# [LightGBM] [Info] Start training from score -25.395471
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000683 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 38.919795
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000566 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score -27.779745
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000524 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 15.761721
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001040 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score -0.533091
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000785 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2898, number of used features: 48
# [LightGBM] [Info] Start training from score 25.587901
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000709 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2898, number of used features: 48
# [LightGBM] [Info] Start training from score 3.816283
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000658 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3030, number of used features: 48
# [LightGBM] [Info] Start training from score 31.084728
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000502 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3030, number of used features: 48
# [LightGBM] [Info] Start training from score -11.159617
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000501 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 22.990567
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000518 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score -3.025220
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000441 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 1826, number of used features: 48
# [LightGBM] [Info] Start training from score 34.249126
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000730 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 1826, number of used features: 48
# [LightGBM] [Info] Start training from score -8.744766
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000623 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2817, number of used features: 48
# [LightGBM] [Info] Start training from score 32.391188
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000751 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2817, number of used features: 48
# [LightGBM] [Info] Start training from score -9.701108
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000840 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2839, number of used features: 48
# [LightGBM] [Info] Start training from score 23.271788
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000726 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2839, number of used features: 48
# [LightGBM] [Info] Start training from score -2.641889
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000499 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3046, number of used features: 48
# [LightGBM] [Info] Start training from score 42.596514
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000511 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3046, number of used features: 48
# [LightGBM] [Info] Start training from score 8.788829
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000422 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3022, number of used features: 48
# [LightGBM] [Info] Start training from score 41.820981
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000561 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3022, number of used features: 48
# [LightGBM] [Info] Start training from score 5.977032
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000820 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2999, number of used features: 48
# [LightGBM] [Info] Start training from score 42.779069
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000536 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2999, number of used features: 48
# [LightGBM] [Info] Start training from score 9.334642
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000520 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 37.788379
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000639 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score -37.305416
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000960 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3047, number of used features: 48
# [LightGBM] [Info] Start training from score 28.771671
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000860 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3047, number of used features: 48
# [LightGBM] [Info] Start training from score 25.866430
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000801 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 42.697553
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000478 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 6.876680
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000463 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2712, number of used features: 48
# [LightGBM] [Info] Start training from score 10.282470
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000335 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2712, number of used features: 48
# [LightGBM] [Info] Start training from score 45.800630
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000954 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 27.348753
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000872 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 21.151183
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000434 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2884, number of used features: 48
# [LightGBM] [Info] Start training from score 17.359602
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000733 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2884, number of used features: 48
# [LightGBM] [Info] Start training from score 78.187628
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000468 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 45.814992
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000737 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 1.316086
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000793 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2988, number of used features: 48
# [LightGBM] [Info] Start training from score 8.854820
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000487 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2988, number of used features: 48
# [LightGBM] [Info] Start training from score 78.882142
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000643 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3033, number of used features: 48
# [LightGBM] [Info] Start training from score 22.206502
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000729 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3033, number of used features: 48
# [LightGBM] [Info] Start training from score 39.847769
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000791 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2922, number of used features: 48
# [LightGBM] [Info] Start training from score 26.192786
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000482 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2922, number of used features: 48
# [LightGBM] [Info] Start training from score 24.276555
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000481 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2764, number of used features: 48
# [LightGBM] [Info] Start training from score 12.483325
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000760 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2764, number of used features: 48
# [LightGBM] [Info] Start training from score 48.430627
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000835 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2830, number of used features: 48
# [LightGBM] [Info] Start training from score -3.184319
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000817 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2830, number of used features: 48
# [LightGBM] [Info] Start training from score 140.107247
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000340 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2671, number of used features: 48
# [LightGBM] [Info] Start training from score 25.720698
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000512 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2671, number of used features: 48
# [LightGBM] [Info] Start training from score -23.997303
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000459 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 42.707597
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000527 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 6.308769
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000576 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2797, number of used features: 48
# [LightGBM] [Info] Start training from score 14.299045
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000419 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2797, number of used features: 48
# [LightGBM] [Info] Start training from score 36.397535
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000655 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 26.781682
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000513 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score -2.760849
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000804 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3007, number of used features: 48
# [LightGBM] [Info] Start training from score 26.582065
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000698 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3007, number of used features: 48
# [LightGBM] [Info] Start training from score 38.200687
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000522 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2718, number of used features: 48
# [LightGBM] [Info] Start training from score 28.599841
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000763 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2718, number of used features: 48
# [LightGBM] [Info] Start training from score 17.184410
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000665 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3027, number of used features: 48
# [LightGBM] [Info] Start training from score 12.872933
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000677 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3027, number of used features: 48
# [LightGBM] [Info] Start training from score -2.009065
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000901 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2726, number of used features: 48
# [LightGBM] [Info] Start training from score 29.553036
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000752 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2726, number of used features: 48
# [LightGBM] [Info] Start training from score -15.780882
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000540 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2040, number of used features: 48
# [LightGBM] [Info] Start training from score 26.648678
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000596 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2040, number of used features: 48
# [LightGBM] [Info] Start training from score 23.543473
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000492 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2770, number of used features: 48
# [LightGBM] [Info] Start training from score 41.843314
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000941 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2770, number of used features: 48
# [LightGBM] [Info] Start training from score -24.701033
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000482 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2528, number of used features: 48
# [LightGBM] [Info] Start training from score 19.383924
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000774 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2528, number of used features: 48
# [LightGBM] [Info] Start training from score 7.116070
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000593 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score -1.568734
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000556 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 70.814905
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000792 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12216
# [LightGBM] [Info] Number of data points in the train set: 3029, number of used features: 48
# [LightGBM] [Info] Start training from score 41.746723
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000444 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12216
# ...
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 8.124027
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000715 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 54.072618
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000835 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 8.222178
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000478 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2892, number of used features: 48
# [LightGBM] [Info] Start training from score 19.653052
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000362 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2892, number of used features: 48
# [LightGBM] [Info] Start training from score 60.365262
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000655 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3033, number of used features: 48
# [LightGBM] [Info] Start training from score 54.047745
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000646 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3033, number of used features: 48
# [LightGBM] [Info] Start training from score 5.509861
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000521 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3043, number of used features: 48
# [LightGBM] [Info] Start training from score 54.803531
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000700 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3043, number of used features: 48
# [LightGBM] [Info] Start training from score 8.419604
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000509 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 51.880825
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000870 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 1.675938
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000499 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2881, number of used features: 48
# [LightGBM] [Info] Start training from score 34.060239
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000557 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2881, number of used features: 48
# [LightGBM] [Info] Start training from score -4.415744
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000686 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2827, number of used features: 48
# [LightGBM] [Info] Start training from score 18.905711
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000750 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2827, number of used features: 48
# [LightGBM] [Info] Start training from score -39.497464
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000474 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2714, number of used features: 48
# [LightGBM] [Info] Start training from score 1.334329
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000500 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2714, number of used features: 48
# [LightGBM] [Info] Start training from score -29.575487
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000501 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3025, number of used features: 48
# [LightGBM] [Info] Start training from score 49.650109
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000502 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3025, number of used features: 48
# [LightGBM] [Info] Start training from score -0.911196
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000869 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 48.021891
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000462 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score -0.362429
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000789 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2930, number of used features: 48
# [LightGBM] [Info] Start training from score 26.389319
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000864 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2930, number of used features: 48
# [LightGBM] [Info] Start training from score 35.807925
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000779 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 52.420109
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000504 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 1.691137
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000497 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2991, number of used features: 48
# [LightGBM] [Info] Start training from score 34.934175
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000544 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2991, number of used features: 48
# [LightGBM] [Info] Start training from score 137.844114
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000444 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2348, number of used features: 48
# [LightGBM] [Info] Start training from score 32.023863
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000377 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2348, number of used features: 48
# [LightGBM] [Info] Start training from score 124.016668
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000464 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2570, number of used features: 48
# [LightGBM] [Info] Start training from score 0.942181
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000762 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2570, number of used features: 48
# [LightGBM] [Info] Start training from score 153.130818
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000509 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2946, number of used features: 48
# [LightGBM] [Info] Start training from score -4.002523
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000500 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2946, number of used features: 48
# [LightGBM] [Info] Start training from score 152.311894
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000499 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2809, number of used features: 48
# [LightGBM] [Info] Start training from score 37.754427
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000641 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 2809, number of used features: 48
# [LightGBM] [Info] Start training from score -57.822056
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000499 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 47.849156
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000505 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score -1.527302
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000460 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 47.849156
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000668 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score -1.527302
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000486 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 48.529266
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000600 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score -3.196409
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000584 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 55.048386
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000807 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 15.572935
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000494 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score 49.771527
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000645 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3048, number of used features: 48
# [LightGBM] [Info] Start training from score -0.321709
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000689 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3026, number of used features: 48
# [LightGBM] [Info] Start training from score 55.770896
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000518 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12240
# [LightGBM] [Info] Number of data points in the train set: 3026, number of used features: 48
# [LightGBM] [Info] Start training from score 12.341098

# %%
# Initialize a list to store submission rows
submission_rows = []

# Generate predictions for the submission file
for idx, row in test_df.iterrows():
    vessel_id = row['vesselId']
    test_time = row['time']
    test_id = row['ID']  # Assuming 'ID' column exists in test_df
    # Check if predictions are available for this vessel_id
    if vessel_id in predictions:
        forecast_ts, last_time = predictions[vessel_id]
        time_diff = (test_time - last_time).total_seconds() / 3600
        index = int(np.round(time_diff)) - 1  # Adjust index since forecast starts from last_time + 1 hour
        # Convert forecast_ts to DataFrame
        forecast_df = forecast_ts.pd_dataframe()
        # Check if index is within forecast horizon
        if 0 <= index < len(forecast_df):
            predicted_lat = forecast_df['latitude'].iloc[index]
            predicted_lon = forecast_df['longitude'].iloc[index]
        else:
            predicted_lat = np.nan
            predicted_lon = np.nan
    else:
        predicted_lat = np.nan
        predicted_lon = np.nan
    # Append the prediction to the submission list
    submission_rows.append({
        'ID': test_id,
        'longitude_predicted': predicted_lon,
        'latitude_predicted': predicted_lat
    })

# Create a submission DataFrame from the list
submission_df = pd.DataFrame(submission_rows)

# Save the submission file
submission_df.to_csv('submission.csv', index=False)

print(submission_df)
# Out:
#           ID  longitude_predicted  latitude_predicted
# 0          0           -81.493484           31.194148
# 1          1           120.274732           14.875803
# 2          2            10.794587           38.388212
# 3          3           172.830545          -43.522142
# 4          4            -6.272242           48.275956
# ...      ...                  ...                 ...
# 51734  51734           -77.939835           26.050946
# 51735  51735           150.623769          -20.137323
# 51736  51736           141.261846           35.258175
# 51737  51737            22.212713           59.146185
# 51738  51738             9.847590           56.299677
#
# [51739 rows x 3 columns]
